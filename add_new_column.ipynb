# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
data = pd.read_csv("raw_analyst_ratings_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0       21991  UBS Maintains Buy on Adobe, Raises Price Targe...
# 1       21992          Stocks That Hit 52-Week Highs On Thursday
# 2       21993  Shares of several companies in the broader tec...
# 3       21994           Stocks That Hit 52-Week Highs On Tuesday
# 4       21995  Shares of several technology companies are tra...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16202690/u...  Benzinga Newsdesk
# 1  https://www.benzinga.com/news/20/06/16180865/s...  Benzinga Insights
# 2  https://www.benzinga.com/wiim/20/05/16116988/s...  Benzinga Newsdesk
# 3  https://www.benzinga.com/news/20/05/16106805/s...  Benzinga Insights
# 4  https://www.benzinga.com/wiim/20/05/16075931/s...  Benzinga Newsdesk
#
#                         date stock
# 0  2020-06-08 10:57:41-04:00  ADBE
# 1  2020-06-04 10:48:11-04:00  ADBE
# 2  2020-05-27 10:24:38-04:00  ADBE
# 3  2020-05-26 10:32:14-04:00  ADBE
# 4  2020-05-20 10:19:31-04:00  ADBE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107805 entries, 0 to 107804
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  107805 non-null  int64
#  1   headline    107805 non-null  object
#  2   url         107805 non-null  object
#  3   publisher   107805 non-null  object
#  4   date        107805 non-null  object
#  5   stock       107805 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 4.9+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0
# count  1.078050e+05
# mean   6.428957e+05
# std    3.850003e+05
# min    2.199100e+04
# 25%    2.651510e+05
# 50%    7.094280e+05
# 75%    8.972850e+05
# max    1.411295e+06

# %%
data.isnull()
# Out:
#         Unnamed: 0  headline    url  publisher   date  stock
# 0            False     False  False      False  False  False
# 1            False     False  False      False  False  False
# 2            False     False  False      False  False  False
# 3            False     False  False      False  False  False
# 4            False     False  False      False  False  False
# ...            ...       ...    ...        ...    ...    ...
# 107800       False     False  False      False  False  False
# 107801       False     False  False      False  False  False
# 107802       False     False  False      False  False  False
# 107803       False     False  False      False  False  False
# 107804       False     False  False      False  False  False
#
# [107805 rows x 6 columns]

# %%
con = sqlite3.connect("ratings.db")
cur = con.cursor()
cur.execute("""
            CREATE TABLE IF NOT EXISTS articles(
            article_id INTEGER PRIMARY KEY,
            headline TEXT NOT NULL,
            url TEXT,
            publisher TEXT,
            published_at TEXT NOT NULL,
            ticker TEXT NOT NULL)
            """)

cur.execute("""
            CREATE TABLE IF NOT EXISTS returns(
            article_id INTEGER PRIMARY KEY,
            return_7d REAL,
            return_30d REAL,
            return_6m0 REAL,
            price TEXT,
            FOREIGN KEY(article_id) REFERENCES articles(article_id))
            """)

cur.execute("""
            CREATE TABLE IF NOT EXISTS sentiment(
            article_id INTEGER PRIMARY KEY,
            sentiment_score REAL,
            sentiment_label REAL,
            method TEXT,
            FOREIGN KEY(article_id) REFERENCES articles(article_id))
            """)
